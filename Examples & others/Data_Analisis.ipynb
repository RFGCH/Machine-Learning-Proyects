# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Leer un archivo

# %%
data = pd.read_csv("/content/sample_data/california_housing_test.csv")
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# Cabeceras: 5 primeros elementos

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Tail: 5 ultimos elementos

# %%
data.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# Sobreescribir los nombres de las columnas

# %%
n_cabeceras = ["longitud", "latitud", "edad_media", "cant_cuartos", "cant_habitaciones","población","hogares","ingreso_mediano", "valor_casa_mediana"]
data.columns = n_cabeceras
data
# Out:
#       longitud  latitud  edad_media  cant_cuartos  cant_habitaciones  \
# 0      -122.05    37.37        27.0        3885.0              661.0
# 1      -118.30    34.26        43.0        1510.0              310.0
# 2      -117.81    33.78        27.0        3589.0              507.0
# 3      -118.36    33.82        28.0          67.0               15.0
# 4      -119.67    36.33        19.0        1241.0              244.0
# ...        ...      ...         ...           ...                ...
# 2995   -119.86    34.42        23.0        1450.0              642.0
# 2996   -118.14    34.06        27.0        5257.0             1082.0
# 2997   -119.70    36.30        10.0         956.0              201.0
# 2998   -117.12    34.10        40.0          96.0               14.0
# 2999   -119.63    34.42        42.0        1765.0              263.0
#
#       población  hogares  ingreso_mediano  valor_casa_mediana
# 0        1537.0    606.0           6.6085            344700.0
# ...

# %% [markdown]
# Guardar archivos

# %%
ruta = "./casas.csv"
data.to_csv(ruta)

# %% [markdown]
# Analisis de datos

# %% [markdown]
# Tipos

# %%
data.dtypes
# Out:
# longitud              float64
# latitud               float64
# edad_media            float64
# cant_cuartos          float64
# cant_habitaciones     float64
# población             float64
# hogares               float64
# ingreso_mediano       float64
# valor_casa_mediana    float64
# dtype: object

# %% [markdown]
# Resumen estadistico

# %%
data.describe()
# Out:
#           longitud     latitud   edad_media  cant_cuartos  cant_habitaciones  \
# count  3000.000000  3000.00000  3000.000000   3000.000000        3000.000000
# mean   -119.589200    35.63539    28.845333   2599.578667         529.950667
# std       1.994936     2.12967    12.555396   2155.593332         415.654368
# min    -124.180000    32.56000     1.000000      6.000000           2.000000
# 25%    -121.810000    33.93000    18.000000   1401.000000         291.000000
# 50%    -118.485000    34.27000    29.000000   2106.000000         437.000000
# 75%    -118.020000    37.69000    37.000000   3129.000000         636.000000
# max    -114.490000    41.92000    52.000000  30450.000000        5419.000000
#
#           población     hogares  ingreso_mediano  valor_casa_mediana
# count   3000.000000  3000.00000      3000.000000          3000.00000
# mean    1402.798667   489.91200         3.807272        205846.27500
# std     1030.543012   365.42271         1.854512        113119.68747
# ...

# %%
data.describe(include = "all")
# Out:
#           longitud     latitud   edad_media  cant_cuartos  cant_habitaciones  \
# count  3000.000000  3000.00000  3000.000000   3000.000000        3000.000000
# mean   -119.589200    35.63539    28.845333   2599.578667         529.950667
# std       1.994936     2.12967    12.555396   2155.593332         415.654368
# min    -124.180000    32.56000     1.000000      6.000000           2.000000
# 25%    -121.810000    33.93000    18.000000   1401.000000         291.000000
# 50%    -118.485000    34.27000    29.000000   2106.000000         437.000000
# 75%    -118.020000    37.69000    37.000000   3129.000000         636.000000
# max    -114.490000    41.92000    52.000000  30450.000000        5419.000000
#
#           población     hogares  ingreso_mediano  valor_casa_mediana
# count   3000.000000  3000.00000      3000.000000          3000.00000
# mean    1402.798667   489.91200         3.807272        205846.27500
# std     1030.543012   365.42271         1.854512        113119.68747
# ...

# %% [markdown]
# Con una columna

# %%
data['longitud'].head()
# Out:
# 0   -122.05
# 1   -118.30
# 2   -117.81
# 3   -118.36
# 4   -119.67
# Name: longitud, dtype: float64

# %%
data[['longitud','latitud','edad_media']].head()
# Out:
#    longitud  latitud  edad_media
# 0   -122.05    37.37        27.0
# 1   -118.30    34.26        43.0
# 2   -117.81    33.78        27.0
# 3   -118.36    33.82        28.0
# 4   -119.67    36.33        19.0

# %% [markdown]
# Con una fila

# %%
data.iloc[0,:].head()
# Out:
# longitud             -122.05
# latitud                37.37
# edad_media             27.00
# cant_cuartos         3885.00
# cant_habitaciones     661.00
# Name: 0, dtype: float64

# %%
data.iloc[0:3,:].head()
# Out:
#    longitud  latitud  edad_media  cant_cuartos  cant_habitaciones  población  \
# 0   -122.05    37.37        27.0        3885.0              661.0     1537.0
# 1   -118.30    34.26        43.0        1510.0              310.0      809.0
# 2   -117.81    33.78        27.0        3589.0              507.0     1484.0
#
#    hogares  ingreso_mediano  valor_casa_mediana
# 0    606.0           6.6085            344700.0
# 1    277.0           3.5990            176500.0
# 2    495.0           5.7934            270500.0

# %% [markdown]
# Mascara booleana: es un filtro que toma los valores que cumplen una condicion especifica

# %%
mascara = data["longitud"]<-120
data[mascara].head()
# Out:
#     longitud  latitud  edad_media  cant_cuartos  cant_habitaciones  población  \
# 0    -122.05    37.37        27.0        3885.0              661.0     1537.0
# 6    -121.43    38.63        43.0        1009.0              225.0      604.0
# 7    -120.65    35.48        19.0        2310.0              471.0     1341.0
# 8    -122.84    38.40        15.0        3080.0              617.0     1446.0
# 12   -121.93    37.25        36.0        1089.0              182.0      535.0
#
#     hogares  ingreso_mediano  valor_casa_mediana
# 0     606.0           6.6085            344700.0
# 6     218.0           1.6641             67000.0
# 7     441.0           3.2250            166900.0
# 8     599.0           3.6696            194400.0
# 12    170.0           4.6900            252600.0

# %%
mascara = (data["longitud"]<-120) & (data["longitud"]>-121)
data[mascara].head()
# Out:
#     longitud  latitud  edad_media  cant_cuartos  cant_habitaciones  población  \
# 7    -120.65    35.48        19.0        2310.0              471.0     1341.0
# 16   -120.81    37.53        15.0         570.0              123.0      189.0
# 50   -120.99    37.70        14.0        9849.0             1887.0     4356.0
# 75   -120.79    37.49        44.0        1186.0              225.0      687.0
# 80   -120.69    37.40        46.0         860.0              130.0      496.0
#
#     hogares  ingreso_mediano  valor_casa_mediana
# 7     441.0           3.2250            166900.0
# 16    107.0           1.8750            181300.0
# 50   1780.0           3.5877            160900.0
# 75    234.0           3.4167            160700.0
# 80    147.0           3.5167            137500.0

# %% [markdown]
# Leer el database house

# %%
data = pd.read_csv("house.csv")
data = data.iloc[:,:]
data.describe()
# Out:
#                id         city          area        rooms     bathroom  \
# count  6080.00000  6080.000000   6080.000000  6080.000000  6080.000000
# mean   3039.50000     0.863322    151.143914     2.492599     2.341612
# std    1755.28915     0.343535    375.559485     1.129665     1.438860
# min       0.00000     0.000000     10.000000     1.000000     1.000000
# 25%    1519.75000     1.000000     58.000000     2.000000     1.000000
# 50%    3039.50000     1.000000    100.000000     3.000000     2.000000
# 75%    4559.25000     1.000000    200.000000     3.000000     3.000000
# max    6079.00000     1.000000  24606.000000    10.000000    10.000000
#
#        parking spaces        floor       animal    furniture            hoa  \
# count     6080.000000  6080.000000  6080.000000  6080.000000    6080.000000
# mean         1.756250     5.672204     0.767434     0.260197    1088.426480
# std          1.611909     6.168918     0.422502     0.438778    3981.357627
# ...

# %%
corr_matrix = data.corr()
corr_matrix
# Out:
#                       id      city      area     rooms  bathroom  \
# id              1.000000  0.000892  0.009544 -0.007723 -0.011691
# city            0.000892  1.000000  0.007710  0.035331  0.089149
# area            0.009544  0.007710  1.000000  0.266957  0.275485
# rooms          -0.007723  0.035331  0.266957  1.000000  0.746876
# bathroom       -0.011691  0.089149  0.275485  0.746876  1.000000
# parking spaces -0.006102  0.031027  0.252492  0.624972  0.685879
# floor          -0.001274  0.076117 -0.031817 -0.081185 -0.000578
# animal         -0.021907 -0.033165  0.064992  0.203533  0.153979
# furniture      -0.002977  0.107194 -0.021375 -0.087379  0.017085
# hoa            -0.016802  0.043221  0.043941  0.126235  0.152157
# rent amount    -0.019286  0.210231  0.236068  0.533534  0.655381
# property tax    0.010927  0.021291  0.032677  0.044465  0.064849
# fire insurance -0.015942  0.192368  0.247435  0.555966  0.664893
# ...

# %%
##Existen las siguientes relaciones
##Habitaciones y Baños con pendiente positiva
##Habitaciones y Lugares para parkear con pendiente positiva
##Habitaciones y el precio de la renta con pendiente positiva
##Habitaciones y seguro contra fuego con pendiente positiva
##Seguro contra fuego y precio de la renta con pendiente positiva

# %%
X = data["rooms"]
Y = data["bathroom"]

# %%
np.reshape(X.to_numpy(),(X.shape[0],1))
# Out:
# array([[3],
#        [2],
#        [5],
#        ...,
#        [1],
#        [3],
#        [2]])

# %%
X.shape
# Out:
# (6080,)

# %%
X_media = np.concatenate(X,axis = 0).mean(axis=0)
X_std = np.concatenate(X,axis = 0).std(axis=0)
Y_media = np.concatenate(Y,axis = 0).mean()
Y_std = np.concatenate(Y,axis = 0).std()

X_nor = (X - X_media) / X_std
Y_nor = (Y - Y_media) / Y_std
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-d62e6d54a41e> in <module>()
# ----> 1 X_media = np.concatenate(X,axis = 0).mean(axis=0)
#       2 X_std = np.concatenate(X,axis = 0).std(axis=0)
#       3 Y_media = np.concatenate(Y,axis = 0).mean()
#       4 Y_std = np.concatenate(Y,axis = 0).std()
#       5
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
theta = np.dot(np.dot(np.linalg.inv(np.dot(X_train.T,X_train)),X_train.T),Y_train)
theta
