# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("cars.csv")

# %%
data = data.iloc[:,:]

# %%
data.describe()
# Out:
#             Volume       Weight         CO2
# count    36.000000    36.000000   36.000000
# mean   1611.111111  1292.277778  102.027778
# std     388.975047   242.123889    7.454571
# min     900.000000   790.000000   90.000000
# 25%    1475.000000  1117.250000   97.750000
# 50%    1600.000000  1329.000000   99.000000
# 75%    2000.000000  1418.250000  105.000000
# max    2500.000000  1746.000000  120.000000

# %%
vacios_cnt = data.isnull().sum()
vacios_cnt
# Out:
# Car       0
# Model     0
# Volume    0
# Weight    0
# CO2       0
# dtype: int64

# %%
vol = data["Volume"]
wght = data["Weight"]
co2 = data["CO2"]

# %%
ax1 = plt.subplot()
ax1.set_title('Volumen')
ax1.boxplot(vol)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fb25813b4d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb25814e710>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb2580e7090>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb25814e750>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fb2580d1c10>,
#   <matplotlib.lines.Line2D at 0x7fb2580d14d0>]}

# %%
ax1 = plt.subplot()
ax1.set_title('Weight')
ax1.boxplot(wght)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fb258073c10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb258077c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb258083c90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb258083750>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fb2580771d0>,
#   <matplotlib.lines.Line2D at 0x7fb258077710>]}

# %%
ax1 = plt.subplot()
ax1.set_title('CO2')
ax1.boxplot(co2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fb2580321d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb257fe3f90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb257fecfd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb257feca90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fb257fe3510>,
#   <matplotlib.lines.Line2D at 0x7fb257fe3a50>]}

# %%
corr_matrix = data.corr()
corr_matrix
# Out:
#           Volume    Weight       CO2
# Volume  1.000000  0.753537  0.592082
# Weight  0.753537  1.000000  0.552150
# CO2     0.592082  0.552150  1.000000
